# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
def f(x):
    f = np.sin(x)**2*(np.sign(x+1)+1)*-(np.sign(x-.8)-1) - 2*(np.sign(x+1)-1)*np.sin(-1)**2 + 2*np.sign(x-.8)*np.sin(.8)**2
    return f/2.8322936730942847 + 0.4332891417126131
def theta(x):
    return np.arctan(f(x)/x)

# %%
p = 100000
val = np.arange(-2., 2., 1/p)

# %%
plt.plot(val, f(val))
#plt.scatter(-.9+.27, f(-.9), s=2000, c="red")
plt.show()

# %%
1.227202094693087/2.8322936730942847
# Out:
# 0.4332891417126131
