# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
    return ((4/3*(100*((np.exp(x**2*np.log(2))*(np.sin(x/3)/x)**5)*(
        np.sign(np.abs(x+.1)-.9)-1)/-2) + 3 * (
        np.sign(x+1)-1)/-8) + 0.8055597012543554*(np.sign(x-.8)+1)/2) - 0.5486968449931411)/0.4513031828957479
def theta(x):
    return np.arctan(f(x)/x)

# %%
p = 100000
val = np.arange(-2., 2., 1/p)

# %%
plt.plot(val, f(val))
plt.show()

# %%
np.max(f(val))
# Out:
# 0.4513031828957479
